# %%
#https://www.kaggle.com/chrisbow/an-introduction-to-facebook-ad-analysis-using-r/data

# %%
import os
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('C://Users//Tom Joseph//Downloads//KAG_conversion_data.csv')

# %%
df.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1

# %% [markdown]
# ### Univariate Analysis

# %%
df['xyz_campaign_id'].value_counts().plot.bar()

# %%
df['fb_campaign_id'].nunique()
# Out:
# 691

# %%
age_gender = pd.crosstab(df.age,df.gender)

# %%
age_gender.plot(kind='bar')

# %%
df.dtypes
# Out:
# ad_id                    int64
# xyz_campaign_id          int64
# fb_campaign_id           int64
# age                     object
# gender                  object
# interest                 int64
# Impressions              int64
# Clicks                   int64
# Spent                  float64
# Total_Conversion         int64
# Approved_Conversion      int64
# dtype: object

# %%
df['CTR'] = round((df['Clicks']/df['Impressions'])*100,2)

# %%
df['CPC'] =  round((df['Spent']/df['Clicks']),2)

# %%
sns.heatmap(df.corr(),cmap = 'BuPu',annot=True)

# %%
df.columns
# Out:
# Index(['ad_id', 'xyz_campaign_id', 'fb_campaign_id', 'age', 'gender',
#        'interest', 'Impressions', 'Clicks', 'Spent', 'Total_Conversion',
#        'Approved_Conversion', 'CTR', 'CPC'],
#       dtype='object')

# %%
df['xyz_campaign_id'].nunique()
# Out:
# 3

# %%
sns.boxplot(x='xyz_campaign_id',y='Spent',data=df)

# %%
dfy = df[df['xyz_campaign_id']==1178]

# %%
sns.heatmap((dfy.isna().sum() ).to_frame())

# %%
dfy.head()
# Out:
#        ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 518  1121091             1178          144531  30-34      M        10
# 519  1121092             1178          144531  30-34      M        10
# 520  1121094             1178          144531  30-34      M        10
# 521  1121095             1178          144531  30-34      M        10
# 522  1121096             1178          144531  30-34      M        10
#
#      Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# 518      1194718     141  254.049996                28                   14
# 519       637648      67  122.400000                13                    5
# 520        24362       0    0.000000                 1                    1
# 521       459690      50   86.330001                 5                    2
# 522       750060      86  161.909999                11                    2
#
#       CTR   CPC
# 518  0.01  1.80
# 519  0.01  1.83
# 520  0.00   NaN
# 521  0.01  1.73
# ...

# %%
dfy['age'].value_counts().plot(kind='bar')

# %%
sns.pairplot(df,hue='gender')

# %%
sns.heatmap(dfy.corr(),annot =True,cmap='BuPu')

# %%
main['date']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e73d4c0dfe60> in <module>
# ----> 1 main['date']
#
# NameError: name 'main' is not defined
